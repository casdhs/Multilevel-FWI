# %%
import matplotlib.pyplot as plt 
import os 
import torch
import numpy as np
import torch.nn as nn
from typing import List, Tuple, Optional
import matplotlib.pyplot as plt
import random 
from decimal import Decimal
import deepwave
import warnings
from torchaudio.functional import biquad
from scipy.signal import butter
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as F
from functools import partial
import time
from tools.utils import ComputeSNR,ComputeSSIM,ComputeRE
warnings.filterwarnings('ignore')
import os
from tools.regularization import*
from tools.tools import *
from pyramid_loss import gaussian_kernel, create_laplacian_pyramid
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
gpu_count = torch.cuda.device_count()
print(f"The number of available GPUs is: {gpu_count}")
if torch.cuda.is_available():
    DEVICE = torch.device("cuda:0")  
    print(f"The selected GPU device is: {torch.cuda.get_device_name(DEVICE)}")
else:
    DEVICE = torch.device("cpu")
    print("No available GPUs detected, switched to using CPU")
# Out:
# The number of available GPUs is: 1
# The selected GPU device is: NVIDIA GeForce RTX 4090

# %%
### load vp_true and linear initial model
vp_true    = torch.tensor(np.load('./model_data/vp_truex200x868.npy')).to(DEVICE)
vp_initial =  torch.tensor(np.load('./model_data/vp_initx200x868.npy')).to(DEVICE)

dx, dz = 25,25 ## m

### show true and initial
print("vp_true max min",vp_true.max(),vp_true.min())

fig, ax = plt.subplots(1, 2, figsize=(9, 6))
fig1 = ax[0].imshow(vp_true.cpu().numpy(), cmap= 'jet',vmin = vp_true.min(),vmax = vp_true.max())
ax[0].set_ylabel("Depth (km)\n",fontsize=9)
fig2 = ax[1].imshow(vp_initial.cpu().numpy(), cmap= 'jet',vmin = vp_true.min(),vmax = vp_true.max())
plt.subplots_adjust(hspace=-0.84,wspace=0.08) 
plt.show()
print("max values:",vp_true.max())
print("min values:",vp_true.min())
# Out:
# torch.Size([200, 868])
# torch.float32
# vp_true max min tensor(4790., device='cuda:0') tensor(1473.4270, device='cuda:0')
# max values: tensor(4790., device='cuda:0')
# min values: tensor(1473.4270, device='cuda:0')

# %%
# ==============================================
# Full Waveform Inversion Configuration
# ==============================================
test_low_fre = 'yes'    # Enable low-frequency testing ('yes'/'no')
cutoff_fre = 1.0      # Cutoff frequency for filtering (Hz)
corners = 16.0          # Filter corners/order for frequency testing

# --------------------------
# Noise Testing Parameters  
# --------------------------
test_low_noise = 'yes'  # Enable noise testing ('yes'/'no')
noise_level = 5      # Standard deviation of Gaussian noise to add
# --------------------------
# learning rate  
# --------------------------
learn = 30
# --------------------------
# Optimization Parameters
# --------------------------
mini_batches = 20      # Number of mini-batches for stochastic optimization
ITERATION = 20        # Total number of optimization iterations

# --------------------------
# Loss Function Configuration
# --------------------------
loss_fn = 'l1'  # Options: 'l1', 'l2'
                

# --------------------------
# pyramid parameters
# --------------------------
kernel_size = 5     ## Gaussian kernel size
levels  = 6         ## number of levels
sigma = 3           ## Gaussian function standard deviation


submarine = "no"                              
submarine_deep = 34                              #water layer deep
submarine_vp = 1486.0002


# --------------------------
#  forward parameters
# --------------------------
DT = 0.008                                              
F_PEAK = 6.0                                            
DH = dx                                                  
N_SHOTS = 60                                             
N_SOURCE_PER_SHOT = 1
model_shape = [vp_true.shape[0],vp_true.shape[1]]
NT = 2000

inpa = {
    'ns': N_SHOTS,               # Number of shots
    'nr': 852,
    'dh': dx,                    # Spatial sampling (m)
    'dt': DT,                    # Time sampling (s)
    'nt': NT,                      # Recording duration (s)
    'accuracy': 4,
    'pml_width': [20, 20, 20, 20]
}

# --------------------------
### save path
# --------------------------

vp_save_path = f'./rec/fwi_ml_lap_noise_{noise_level}/'
if not os.path.exists(vp_save_path):
    os.makedirs(vp_save_path)

main_path = f'./log_data/fwi_ml_lap_noise_{noise_level}/'
if not os.path.exists(main_path):
    os.makedirs(main_path)
# Out:
# ┌───────────────────────┬───────────────────────┐
# │       参数名称        │        参数值        │
# ├───────────────────────┼───────────────────────┤
# │ Misfit function         │ 'l1'                                    │
# │ Test Loss Low frequency │ 'yes'                                   │
# │ Cutoff Frequency        │ 1.0 Hz                                  │
# │ Butter Order            │ 16.0                                    │
# │ Test Noise              │ 'yes'                                   │
# │ Noise Level             │ 5                                       │
# │ Test With Outers        │ 'no'                                    │
# │ Outers Interval         │ 6                                       │
# │ mini_batches            │ 20                                      │
# │ ITERATION               │ 30                                      │
# │ learning rate           │ 30                                      │
# │ vp_save_path            │ ./noise_test/fwi_l1_lap_ml_noise_5/     │
# │ log_data save path      │ ./log_noise_test/fwi_l1_lap_ml_noise_5/ │
# └───────────────────────┴───────────────────────┘

# %%
#### load source receiver position and source wavelet

src_loc = torch.tensor(np.load('./src_rec_loc/src_loc.npy')).to(DEVICE)
rec_loc = torch.tensor(np.load('./src_rec_loc/rec_loc.npy')).to(DEVICE)
src = torch.tensor(np.load('./source/src.npy')).to(DEVICE)

### load obs data
d_obs = torch.tensor(np.load('./obs_data/d_obs.npy')).to(DEVICE)
# Out:
# NT: 2000

# %%
criteria1 = torch.nn.L1Loss(reduction='sum') ### for model loss
 
vp0 = vp_initial.to(DEVICE)
vp0 = vp0.requires_grad_(True)

optimer = torch.optim.Adam([{'params': [vp0], 'lr': learn,'betas': (0.9, 0.98)}])

all_loss_data = []
all_loss_model =[]
time_each_iter = []
tv_loss = []
SNR = []
cpu_mem_log = [] 
gpu_mem_log = []

# %%
t_start = time.time()

kernel_size = kernel_size
levels  = levels
sigma = sigma


levels_1 = np.arange(0,levels,1)

for level in reversed(levels_1):
    print('Now inversion on level:',level)
    for iter in range(ITERATION):
        loss_data_minibatch = []
        time_each_bath_start = time.time()
        
        for batch in range(mini_batches):
        
            optimer.zero_grad()
            src_loc_batch = src_loc[batch::mini_batches]
            rec_loc_batch = rec_loc[batch::mini_batches]
            src_batch = src[batch::mini_batches]
                        
            physics = Physics_deepwave(inpa['dh'], inpa['dt'], src=src_batch,
                                src_loc=src_loc_batch, rec_loc=rec_loc_batch,
                                       accuracy = inpa['accuracy'],
                                    pml_width =  inpa['pml_width']
                                )
                
            with torch.no_grad():
                if submarine == "yes":
                    vp0[:submarine_deep,:] = submarine_vp
                else:
                    vp0 = vp0
                    
                vp0[vp0>vp_true.max()] = vp_true.max()
                vp0[vp0<vp_true.min()] = vp_true.min() 
                
            vp0 = vp0.requires_grad_(True)
            taux_est = physics(vp0.squeeze()) ###[1,shots_batch,nt,receviers]
    
            d_obs1 = d_obs.unsqueeze(0)
      
            taux_est_filtered = taux_est
            d_obs_filtered = d_obs1[:, batch::mini_batches]
            
            lam_tv = 0#0.001
            tvloss = tv_l1_regularization(vp0)
            #taux_est_filtered = (taux_est_filtered - torch.mean(taux_est_filtered)) / torch.std(taux_est_filtered)
            #d_obs_filtered = (d_obs_filtered - torch.mean(d_obs_filtered)) / torch.std(d_obs_filtered)
           
            channels = taux_est.shape[1]
            
            dtype = torch.float
            kernel = gaussian_kernel(size=kernel_size, channels=channels, sigma=sigma, dtype=dtype, device=DEVICE)
            
            
            pyramids_obs = create_laplacian_pyramid(d_obs_filtered, kernel=kernel, levels=levels
                                                        )
            pyramids_syn = create_laplacian_pyramid(taux_est_filtered, kernel=kernel, levels=levels
                                                        )
#             for i in range(7):
#                 print('pyramids_syn.shape',pyramids_syn[i].shape)
            if loss_fn == 'l1':
                criteria = torch.nn.L1Loss(reduction='mean')
                weight = 1.0e2
            else:
                criteria =  torch.nn.MSELoss(reduction='mean')
                weight = 1.0e4
            
            loss_data = weight*criteria(pyramids_obs[level],pyramids_syn[level])
    
            loss = loss_data
            loss.backward()
            
            optimer.step()
                  
            loss_data = loss.item()
        
        all_loss_data.append(np.mean(loss_data))
        time_each_bath_end = time.time()
        tv_loss.append(lam_tv*tvloss)
        
        time_each_iter.append(time_each_bath_end - time_each_bath_start)
        
        mem_now_cpu = get_cpu_memory()
        cpu_mem_log.append(mem_now_cpu)
        mem_now_gpu = get_gpu_memory()
        gpu_mem_log.append(mem_now_gpu)
        
        snr = ComputeSNR(vp0.detach().cpu().numpy(), \
                      vp_true.detach().cpu().numpy())
        SNR = np.append(SNR, snr)
        with torch.no_grad():
            all_loss_model.append(
                criteria1(vp0, vp_true).item()
            )
        if (iter+1)%1 ==0:
            print(f"Iter {iter + 1} = loss: {all_loss_data[-1]:.4f},model: {all_loss_model[-1]:.4f},time_iter:{time_each_iter[-1]:.4f},tvloss:{tv_loss[-1]:.2f},snr_vp:{SNR[-1]:.3f}")
        if (iter+1)%10 ==0:
            np.save(vp_save_path + 'recx_iter_%s_%s.npy' % (iter + 1, level), vp0.cpu().detach().numpy())
        if (iter+1)%10 == 0:   
            fig, ax = plt.subplots(1,1, figsize=(4, 4))
            im = ax.imshow(vp0.detach().cpu(), 
                              cmap='jet', vmin=vp0.min(), 
                       vmax=vp0.max()) 
            points = ax.get_position().get_points()
            dy = points[1, 1] - points[0, 1]
    
            cax = fig.add_axes([0.91, points[0, 1], 0.02, dy])
            cax.yaxis.set_ticks_position("right")
            cbar = fig.colorbar(im, cax=cax, orientation="vertical", 
                                extend="neither", label="$V_P (m/s)$"
                                )
            plt.show()
        #scheduler_transfomerdecoder.step()    
t_end = time.time()
elapsed_time = t_end - t_start
print('Running complete in {:.0f}m  {:.0f}s' .format(elapsed_time //60 , elapsed_time % 60))
# Out:
# Now inversion on level: 4
# Iter 1 = loss: 1.3388,model: 85071440.0000,time_iter:3.8088,tvloss:0.00,snr_vp:13.621
# Iter 2 = loss: 1.2572,model: 85223240.0000,time_iter:3.7292,tvloss:0.00,snr_vp:13.556
# Iter 3 = loss: 1.2151,model: 84904064.0000,time_iter:3.7193,tvloss:0.00,snr_vp:13.504
# Iter 4 = loss: 1.1780,model: 84689248.0000,time_iter:3.7138,tvloss:0.00,snr_vp:13.485
# Iter 5 = loss: 1.1626,model: 84119232.0000,time_iter:3.7076,tvloss:0.00,snr_vp:13.513
# Iter 6 = loss: 1.1414,model: 83807072.0000,time_iter:3.7188,tvloss:0.00,snr_vp:13.540
# Iter 7 = loss: 1.1290,model: 83436712.0000,time_iter:3.7315,tvloss:0.00,snr_vp:13.569
# Iter 8 = loss: 1.1078,model: 83040880.0000,time_iter:3.7297,tvloss:0.00,snr_vp:13.617
# Iter 9 = loss: 1.1045,model: 82611984.0000,time_iter:3.7211,tvloss:0.00,snr_vp:13.665
# Iter 10 = loss: 1.0814,model: 82412888.0000,time_iter:3.7262,tvloss:0.00,snr_vp:13.711
# Iter 11 = loss: 1.0777,model: 81942800.0000,time_iter:3.7591,tvloss:0.00,snr_vp:13.769
# Iter 12 = loss: 1.0680,model: 81318200.0000,time_iter:3.7620,tvloss:0.00,snr_vp:13.829
# Iter 13 = loss: 1.0614,model: 80700672.0000,time_iter:3.7501,tvloss:0.00,snr_vp:13.884
# Iter 14 = loss: 1.0566,model: 79735096.0000,time_iter:3.7361,tvloss:0.00,snr_vp:13.955
# Iter 15 = loss: 1.0523,model: 78757440.0000,time_iter:3.7385,tvloss:0.00,snr_vp:14.024
# Iter 16 = loss: 1.0447,model: 77651504.0000,time_iter:3.7791,tvloss:0.00,snr_vp:14.093
# Iter 17 = loss: 1.0411,model: 76473904.0000,time_iter:3.7985,tvloss:0.00,snr_vp:14.180
# Iter 18 = loss: 1.0262,model: 75072512.0000,time_iter:3.7575,tvloss:0.00,snr_vp:14.259
# Iter 19 = loss: 1.0234,model: 74036792.0000,time_iter:3.7529,tvloss:0.00,snr_vp:14.353
# Iter 20 = loss: 1.0082,model: 72424544.0000,time_iter:3.8033,tvloss:0.00,snr_vp:14.434
# Iter 21 = loss: 1.0095,model: 71223408.0000,time_iter:3.7649,tvloss:0.00,snr_vp:14.530
# Iter 22 = loss: 0.9998,model: 69774256.0000,time_iter:3.7540,tvloss:0.00,snr_vp:14.614
# Iter 23 = loss: 0.9863,model: 68762968.0000,time_iter:3.7975,tvloss:0.00,snr_vp:14.697
# Iter 24 = loss: 0.9960,model: 67470928.0000,time_iter:3.7552,tvloss:0.00,snr_vp:14.775
# Iter 25 = loss: 0.9886,model: 66274872.0000,time_iter:3.7905,tvloss:0.00,snr_vp:14.865
# Iter 26 = loss: 0.9753,model: 65297356.0000,time_iter:3.8010,tvloss:0.00,snr_vp:14.917
# Iter 27 = loss: 0.9837,model: 63722204.0000,time_iter:3.8101,tvloss:0.00,snr_vp:15.035
# Iter 28 = loss: 0.9625,model: 63036900.0000,time_iter:3.7685,tvloss:0.00,snr_vp:15.070
# Iter 29 = loss: 0.9623,model: 61695324.0000,time_iter:3.7906,tvloss:0.00,snr_vp:15.183
# Iter 30 = loss: 0.9524,model: 61087880.0000,time_iter:3.7474,tvloss:0.00,snr_vp:15.227
# Now inversion on level: 3
# Iter 1 = loss: 2.6290,model: 58411664.0000,time_iter:3.7146,tvloss:0.00,snr_vp:15.459
# Iter 2 = loss: 2.4576,model: 56487872.0000,time_iter:3.7160,tvloss:0.00,snr_vp:15.642
# Iter 3 = loss: 2.3253,model: 55092304.0000,time_iter:3.7158,tvloss:0.00,snr_vp:15.794
# Iter 4 = loss: 2.2890,model: 53799832.0000,time_iter:3.7213,tvloss:0.00,snr_vp:15.913
# Iter 5 = loss: 2.2435,model: 53130776.0000,time_iter:3.7592,tvloss:0.00,snr_vp:16.011
# Iter 6 = loss: 2.2239,model: 52094632.0000,time_iter:3.7232,tvloss:0.00,snr_vp:16.129
# Iter 7 = loss: 2.1834,model: 51754728.0000,time_iter:3.7291,tvloss:0.00,snr_vp:16.216
# Iter 8 = loss: 2.1435,model: 50545096.0000,time_iter:3.7295,tvloss:0.00,snr_vp:16.347
# Iter 9 = loss: 2.1414,model: 50170628.0000,time_iter:3.7628,tvloss:0.00,snr_vp:16.432
# Iter 10 = loss: 2.1272,model: 49185368.0000,time_iter:3.7496,tvloss:0.00,snr_vp:16.550
# Iter 11 = loss: 2.1216,model: 48624464.0000,time_iter:3.7265,tvloss:0.00,snr_vp:16.633
# Iter 12 = loss: 2.0951,model: 47907988.0000,time_iter:3.7275,tvloss:0.00,snr_vp:16.745
# Iter 13 = loss: 2.1172,model: 47069824.0000,time_iter:3.7392,tvloss:0.00,snr_vp:16.857
# Iter 14 = loss: 2.0754,model: 46451672.0000,time_iter:3.7295,tvloss:0.00,snr_vp:16.986
# Iter 15 = loss: 2.0875,model: 45553088.0000,time_iter:3.7422,tvloss:0.00,snr_vp:17.126
# Iter 16 = loss: 2.0530,model: 44774420.0000,time_iter:3.7226,tvloss:0.00,snr_vp:17.292
# Iter 17 = loss: 2.0442,model: 43788232.0000,time_iter:3.7232,tvloss:0.00,snr_vp:17.441
# Iter 18 = loss: 1.9903,model: 43107252.0000,time_iter:3.7426,tvloss:0.00,snr_vp:17.622
# Iter 19 = loss: 2.0200,model: 42190492.0000,time_iter:3.7609,tvloss:0.00,snr_vp:17.751
# Iter 20 = loss: 1.9446,model: 41520656.0000,time_iter:3.7607,tvloss:0.00,snr_vp:17.918
# Iter 21 = loss: 1.9950,model: 40630368.0000,time_iter:3.7434,tvloss:0.00,snr_vp:18.061
# Iter 22 = loss: 1.9159,model: 40069156.0000,time_iter:3.7457,tvloss:0.00,snr_vp:18.221
# Iter 23 = loss: 1.9936,model: 39334808.0000,time_iter:3.7168,tvloss:0.00,snr_vp:18.374
# Iter 24 = loss: 1.8932,model: 38578104.0000,time_iter:3.7223,tvloss:0.00,snr_vp:18.539
# Iter 25 = loss: 1.9409,model: 37928448.0000,time_iter:3.7684,tvloss:0.00,snr_vp:18.692
# Iter 26 = loss: 1.8404,model: 37114240.0000,time_iter:3.7624,tvloss:0.00,snr_vp:18.870
# Iter 27 = loss: 1.8887,model: 36505936.0000,time_iter:3.7780,tvloss:0.00,snr_vp:19.023
# Iter 28 = loss: 1.8237,model: 35791828.0000,time_iter:3.7688,tvloss:0.00,snr_vp:19.190
# Iter 29 = loss: 1.8875,model: 35269456.0000,time_iter:3.7922,tvloss:0.00,snr_vp:19.328
# Iter 30 = loss: 1.8557,model: 34619968.0000,time_iter:3.7369,tvloss:0.00,snr_vp:19.487
# Now inversion on level: 2
# Iter 1 = loss: 4.3682,model: 33872856.0000,time_iter:3.7538,tvloss:0.00,snr_vp:19.657
# Iter 2 = loss: 4.3650,model: 33087600.0000,time_iter:3.7738,tvloss:0.00,snr_vp:19.791
# Iter 3 = loss: 4.4098,model: 32824936.0000,time_iter:3.7559,tvloss:0.00,snr_vp:19.910
# Iter 4 = loss: 4.3384,model: 32345810.0000,time_iter:3.7237,tvloss:0.00,snr_vp:19.997
# Iter 5 = loss: 4.7776,model: 32152448.0000,time_iter:3.7380,tvloss:0.00,snr_vp:20.079
# Iter 6 = loss: 4.3537,model: 31811284.0000,time_iter:3.7654,tvloss:0.00,snr_vp:20.128
# Iter 7 = loss: 4.4964,model: 31658662.0000,time_iter:3.7412,tvloss:0.00,snr_vp:20.170
# Iter 8 = loss: 4.5475,model: 31909792.0000,time_iter:3.7534,tvloss:0.00,snr_vp:20.170
# Iter 9 = loss: 4.3138,model: 31372452.0000,time_iter:3.7177,tvloss:0.00,snr_vp:20.234
# Iter 10 = loss: 4.1171,model: 31098458.0000,time_iter:3.7175,tvloss:0.00,snr_vp:20.294
# Iter 11 = loss: 4.1759,model: 30862260.0000,time_iter:3.7193,tvloss:0.00,snr_vp:20.341
# Iter 12 = loss: 4.2878,model: 30586404.0000,time_iter:3.7334,tvloss:0.00,snr_vp:20.424
# Iter 13 = loss: 4.3457,model: 30688956.0000,time_iter:3.7341,tvloss:0.00,snr_vp:20.465
# Iter 14 = loss: 4.3716,model: 30082880.0000,time_iter:3.7231,tvloss:0.00,snr_vp:20.546
# Iter 15 = loss: 4.0499,model: 29981412.0000,time_iter:3.7235,tvloss:0.00,snr_vp:20.576
# Iter 16 = loss: 4.2104,model: 29685868.0000,time_iter:3.7130,tvloss:0.00,snr_vp:20.637
# Iter 17 = loss: 4.0889,model: 29567156.0000,time_iter:3.7269,tvloss:0.00,snr_vp:20.680
# Iter 18 = loss: 4.2897,model: 29208028.0000,time_iter:3.7409,tvloss:0.00,snr_vp:20.753
# Iter 19 = loss: 4.0890,model: 29204736.0000,time_iter:3.7249,tvloss:0.00,snr_vp:20.780
# Iter 20 = loss: 4.2868,model: 29089452.0000,time_iter:3.7142,tvloss:0.00,snr_vp:20.825
# Iter 21 = loss: 4.2210,model: 29124400.0000,time_iter:3.7236,tvloss:0.00,snr_vp:20.845
# Iter 22 = loss: 4.2071,model: 28963054.0000,time_iter:3.7387,tvloss:0.00,snr_vp:20.896
# Iter 23 = loss: 4.2983,model: 28866148.0000,time_iter:3.7403,tvloss:0.00,snr_vp:20.924
# Iter 24 = loss: 4.2661,model: 28843322.0000,time_iter:3.7480,tvloss:0.00,snr_vp:20.942
# Iter 25 = loss: 4.1844,model: 28781766.0000,time_iter:3.7561,tvloss:0.00,snr_vp:20.941
# Iter 26 = loss: 4.1486,model: 28622552.0000,time_iter:3.7426,tvloss:0.00,snr_vp:20.966
# Iter 27 = loss: 4.3456,model: 28701988.0000,time_iter:3.7495,tvloss:0.00,snr_vp:20.983
# Iter 28 = loss: 4.3374,model: 28569370.0000,time_iter:3.7647,tvloss:0.00,snr_vp:20.989
# Iter 29 = loss: 4.3610,model: 28646756.0000,time_iter:3.7442,tvloss:0.00,snr_vp:20.984
# Iter 30 = loss: 4.4741,model: 28646384.0000,time_iter:3.7442,tvloss:0.00,snr_vp:20.991
# Now inversion on level: 1
# Iter 1 = loss: 9.3871,model: 29020562.0000,time_iter:3.7310,tvloss:0.00,snr_vp:20.969
# Iter 2 = loss: 9.5473,model: 29424808.0000,time_iter:3.7383,tvloss:0.00,snr_vp:20.946
# Iter 3 = loss: 8.8944,model: 28950328.0000,time_iter:3.7906,tvloss:0.00,snr_vp:20.936
# Iter 4 = loss: 8.9786,model: 28524992.0000,time_iter:3.7544,tvloss:0.00,snr_vp:20.980
# Iter 5 = loss: 8.9727,model: 28449906.0000,time_iter:3.8016,tvloss:0.00,snr_vp:20.976
# Iter 6 = loss: 8.9980,model: 28664348.0000,time_iter:3.7421,tvloss:0.00,snr_vp:20.971
# Iter 7 = loss: 9.2175,model: 28551246.0000,time_iter:3.7747,tvloss:0.00,snr_vp:20.975
# Iter 8 = loss: 8.8272,model: 29052302.0000,time_iter:3.7831,tvloss:0.00,snr_vp:20.946
# Iter 9 = loss: 9.3571,model: 28982420.0000,time_iter:3.7587,tvloss:0.00,snr_vp:20.957
# Iter 10 = loss: 8.7976,model: 28814620.0000,time_iter:3.7475,tvloss:0.00,snr_vp:20.964
# Iter 11 = loss: 9.0181,model: 28929272.0000,time_iter:3.7471,tvloss:0.00,snr_vp:20.947
# Iter 12 = loss: 8.4500,model: 28705828.0000,time_iter:3.7536,tvloss:0.00,snr_vp:20.948
# Iter 13 = loss: 8.7480,model: 28830964.0000,time_iter:3.7608,tvloss:0.00,snr_vp:20.960
# Iter 14 = loss: 8.8005,model: 29127506.0000,time_iter:3.7616,tvloss:0.00,snr_vp:20.933
# Iter 15 = loss: 9.3321,model: 29189886.0000,time_iter:3.7537,tvloss:0.00,snr_vp:20.936
# Iter 16 = loss: 8.9022,model: 29366512.0000,time_iter:3.7526,tvloss:0.00,snr_vp:20.921
# Iter 17 = loss: 8.8290,model: 29271792.0000,time_iter:3.7480,tvloss:0.00,snr_vp:20.917
# Iter 18 = loss: 9.3117,model: 29222326.0000,time_iter:3.7397,tvloss:0.00,snr_vp:20.941
# Iter 19 = loss: 8.8113,model: 29029238.0000,time_iter:3.7388,tvloss:0.00,snr_vp:20.936
# Iter 20 = loss: 8.6588,model: 29104116.0000,time_iter:3.7373,tvloss:0.00,snr_vp:20.957
# Iter 21 = loss: 8.7812,model: 28938924.0000,time_iter:3.7596,tvloss:0.00,snr_vp:20.970
# Iter 22 = loss: 8.6454,model: 28923006.0000,time_iter:3.7464,tvloss:0.00,snr_vp:20.981
# Iter 23 = loss: 8.9033,model: 29200674.0000,time_iter:3.7362,tvloss:0.00,snr_vp:20.968
# Iter 24 = loss: 8.8479,model: 29411908.0000,time_iter:3.7139,tvloss:0.00,snr_vp:20.955
# Iter 25 = loss: 9.2340,model: 29302264.0000,time_iter:3.7524,tvloss:0.00,snr_vp:20.963
# Iter 26 = loss: 8.9598,model: 29530784.0000,time_iter:3.7264,tvloss:0.00,snr_vp:20.930
# Iter 27 = loss: 9.0477,model: 29437920.0000,time_iter:3.7528,tvloss:0.00,snr_vp:20.931
# Iter 28 = loss: 8.8225,model: 29647904.0000,time_iter:3.7604,tvloss:0.00,snr_vp:20.910
# Iter 29 = loss: 9.2786,model: 29717098.0000,time_iter:3.7105,tvloss:0.00,snr_vp:20.890
# Iter 30 = loss: 9.0823,model: 29984054.0000,time_iter:3.7196,tvloss:0.00,snr_vp:20.845
# Now inversion on level: 0
# Iter 1 = loss: 45.0753,model: 30173302.0000,time_iter:3.7653,tvloss:0.00,snr_vp:20.810
# Iter 2 = loss: 45.1149,model: 29720382.0000,time_iter:3.7515,tvloss:0.00,snr_vp:20.856
# Iter 3 = loss: 44.6182,model: 29220020.0000,time_iter:3.7472,tvloss:0.00,snr_vp:20.895
# Iter 4 = loss: 45.6111,model: 29125858.0000,time_iter:3.7586,tvloss:0.00,snr_vp:20.929
# Iter 5 = loss: 44.7303,model: 29076660.0000,time_iter:3.7642,tvloss:0.00,snr_vp:20.925
# Iter 6 = loss: 45.0127,model: 29075788.0000,time_iter:3.7629,tvloss:0.00,snr_vp:20.935
# Iter 7 = loss: 45.2027,model: 29225314.0000,time_iter:3.7393,tvloss:0.00,snr_vp:20.901
# Iter 8 = loss: 45.7523,model: 29857666.0000,time_iter:3.7275,tvloss:0.00,snr_vp:20.889
# Iter 9 = loss: 44.8863,model: 29928012.0000,time_iter:3.7186,tvloss:0.00,snr_vp:20.859
# Iter 10 = loss: 44.9679,model: 29756470.0000,time_iter:3.7177,tvloss:0.00,snr_vp:20.875
# Iter 11 = loss: 45.1954,model: 30137082.0000,time_iter:3.7670,tvloss:0.00,snr_vp:20.853
# Iter 12 = loss: 45.1302,model: 29979944.0000,time_iter:3.7945,tvloss:0.00,snr_vp:20.844
# Iter 13 = loss: 45.1945,model: 30184432.0000,time_iter:3.7721,tvloss:0.00,snr_vp:20.813
# Iter 14 = loss: 45.1190,model: 30312474.0000,time_iter:3.7880,tvloss:0.00,snr_vp:20.810
# Iter 15 = loss: 45.0482,model: 30473464.0000,time_iter:3.7638,tvloss:0.00,snr_vp:20.759
# Iter 16 = loss: 45.0759,model: 30338604.0000,time_iter:3.7672,tvloss:0.00,snr_vp:20.788
# Iter 17 = loss: 45.1516,model: 30339852.0000,time_iter:3.7821,tvloss:0.00,snr_vp:20.793
# Iter 18 = loss: 45.1802,model: 30492742.0000,time_iter:3.7633,tvloss:0.00,snr_vp:20.755
# Iter 19 = loss: 44.8212,model: 30710812.0000,time_iter:3.7349,tvloss:0.00,snr_vp:20.718
# Iter 20 = loss: 44.9313,model: 30734416.0000,time_iter:3.7463,tvloss:0.00,snr_vp:20.731
# Iter 21 = loss: 45.4639,model: 30643384.0000,time_iter:3.7422,tvloss:0.00,snr_vp:20.731
# Iter 22 = loss: 44.7001,model: 30769882.0000,time_iter:3.7634,tvloss:0.00,snr_vp:20.730
# Iter 23 = loss: 45.0899,model: 30928374.0000,time_iter:3.7783,tvloss:0.00,snr_vp:20.706
# Iter 24 = loss: 45.0950,model: 30787424.0000,time_iter:3.7375,tvloss:0.00,snr_vp:20.695
# Iter 25 = loss: 44.9383,model: 30643062.0000,time_iter:3.7597,tvloss:0.00,snr_vp:20.701
# Iter 26 = loss: 45.0897,model: 30566370.0000,time_iter:3.7248,tvloss:0.00,snr_vp:20.693
# Iter 27 = loss: 45.1124,model: 30631932.0000,time_iter:3.7260,tvloss:0.00,snr_vp:20.668
# Iter 28 = loss: 45.3671,model: 30886084.0000,time_iter:3.7256,tvloss:0.00,snr_vp:20.648
# Iter 29 = loss: 45.4547,model: 30971888.0000,time_iter:3.7475,tvloss:0.00,snr_vp:20.619
# Iter 30 = loss: 45.0018,model: 30788002.0000,time_iter:3.7166,tvloss:0.00,snr_vp:20.633
# Running complete in 9m  33s

# %%
with torch.no_grad():
    np.savetxt(main_path +'all_loss_data.txt', all_loss_data,delimiter=',')
    np.savetxt(main_path +'elapsed_time.txt', time_each_iter,delimiter=',')
    np.savetxt(main_path + 'all_loss_model.txt', all_loss_model, delimiter=',')
    np.savetxt(main_path + 'snr.txt', SNR, delimiter=',')
    np.savetxt(main_path+'cpu_men_log.txt',cpu_mem_log , delimiter=',')
    np.savetxt(main_path+'gpu_men_log.txt',gpu_mem_log , delimiter=',')

# %%
torch.cuda.empty_cache()
