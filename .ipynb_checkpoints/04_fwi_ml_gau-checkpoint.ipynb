# %%
import matplotlib.pyplot as plt 
import os 
import torch
import numpy as np
import torch.nn as nn
from typing import List, Tuple, Optional
import matplotlib.pyplot as plt
import random 
from decimal import Decimal
import deepwave
import warnings
from torchaudio.functional import biquad
from scipy.signal import butter
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as F
from functools import partial
import time
from tools.utils import ComputeSNR,ComputeSSIM,ComputeRE
warnings.filterwarnings('ignore')
import os
from tools.regularization import*
from tools.tools import *
from pyramid_loss import gaussian_kernel, create_gaussian_pyramid
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
gpu_count = torch.cuda.device_count()
print(f"The number of available GPUs is: {gpu_count}")
if torch.cuda.is_available():
    DEVICE = torch.device("cuda:0")  
    print(f"The selected GPU device is: {torch.cuda.get_device_name(DEVICE)}")
else:
    DEVICE = torch.device("cpu")
    print("No available GPUs detected, switched to using CPU")
# Out:
# The number of available GPUs is: 1
# The selected GPU device is: NVIDIA GeForce RTX 4090

# %%
### load vp_true and linear initial model
vp_true    = torch.tensor(np.load('./model_data/vp_truex200x868.npy')).to(DEVICE)
vp_initial =  torch.tensor(np.load('./model_data/vp_initx200x868.npy')).to(DEVICE)

dx, dz = 25,25 ## m

### show true and initial
print("vp_true max min",vp_true.max(),vp_true.min())

fig, ax = plt.subplots(1, 2, figsize=(9, 6))
fig1 = ax[0].imshow(vp_true.cpu().numpy(), cmap= 'jet',vmin = vp_true.min(),vmax = vp_true.max())
ax[0].set_ylabel("Depth (km)\n",fontsize=9)
fig2 = ax[1].imshow(vp_initial.cpu().numpy(), cmap= 'jet',vmin = vp_true.min(),vmax = vp_true.max())
plt.subplots_adjust(hspace=-0.84,wspace=0.08) 
plt.show()
print("max values:",vp_true.max())
print("min values:",vp_true.min())
# Out:
# torch.Size([200, 868])
# torch.float32
# vp_true max min tensor(4790., device='cuda:0') tensor(1473.4270, device='cuda:0')
# max values: tensor(4790., device='cuda:0')
# min values: tensor(1473.4270, device='cuda:0')

# %%
# ==============================================
# Full Waveform Inversion Configuration
# ==============================================
test_low_fre = 'yes'    # Enable low-frequency testing ('yes'/'no')
cutoff_fre = 1.0      # Cutoff frequency for filtering (Hz)
corners = 16.0          # Filter corners/order for frequency testing

# --------------------------
# Noise Testing Parameters  
# --------------------------
test_low_noise = 'yes'  # Enable noise testing ('yes'/'no')
noise_level = 5      # Standard deviation of Gaussian noise to add
# --------------------------
# learning rate  
# --------------------------
learn = 30
# --------------------------
# Optimization Parameters
# --------------------------
mini_batches = 20      # Number of mini-batches for stochastic optimization
ITERATION = 20        # Total number of optimization iterations

# --------------------------
# Loss Function Configuration
# --------------------------
loss_fn = 'l1'  # Options: 'l1', 'l2'
                

# --------------------------
# pyramid parameters
# --------------------------
kernel_size = 5     ## Gaussian kernel size
levels  = 6         ## number of levels
sigma = 3           ## Gaussian function standard deviation


submarine = "no"                              
submarine_deep = 34                              #water layer deep
submarine_vp = 1486.0002


# --------------------------
#  forward parameters
# --------------------------
DT = 0.008                                              
F_PEAK = 6.0                                            
DH = dx                                                  
N_SHOTS = 60                                             
N_SOURCE_PER_SHOT = 1
model_shape = [vp_true.shape[0],vp_true.shape[1]]
NT = 2000

inpa = {
    'ns': N_SHOTS,               # Number of shots
    'nr': 852,
    'dh': dx,                    # Spatial sampling (m)
    'dt': DT,                    # Time sampling (s)
    'nt': NT,                      # Recording duration (s)
    'accuracy': 4,
    'pml_width': [20, 20, 20, 20]
}

# --------------------------
### save path
# --------------------------

vp_save_path = f'./rec/fwi_ml_gau_noise_{noise_level}/'
if not os.path.exists(vp_save_path):
    os.makedirs(vp_save_path)

main_path = f'./log_data/fwi_ml_gau_noise_{noise_level}/'
if not os.path.exists(main_path):
    os.makedirs(main_path)
# Out:
# ┌───────────────────────┬───────────────────────┐
# │       参数名称        │        参数值        │
# ├───────────────────────┼───────────────────────┤
# │ Misfit function         │ 'l1'                                    │
# │ Test Loss Low frequency │ 'yes'                                   │
# │ Cutoff Frequency        │ 1.0 Hz                                  │
# │ Butter Order            │ 16.0                                    │
# │ Test Noise              │ 'yes'                                   │
# │ Noise Level             │ 5                                       │
# │ Test With Outers        │ 'no'                                    │
# │ Outers Interval         │ 6                                       │
# │ mini_batches            │ 20                                      │
# │ ITERATION               │ 30                                      │
# │ learning rate           │ 30                                      │
# │ vp_save_path            │ ./noise_test/fwi_l1_gau_ml_noise_5/     │
# │ log_data save path      │ ./log_noise_test/fwi_l1_gau_ml_noise_5/ │
# └───────────────────────┴───────────────────────┘

# %% [markdown]
# # ViT-EFWI

# %%
#### load source receiver position and source wavelet

src_loc = torch.tensor(np.load('./src_rec_loc/src_loc.npy')).to(DEVICE)
rec_loc = torch.tensor(np.load('./src_rec_loc/rec_loc.npy')).to(DEVICE)
src = torch.tensor(np.load('./source/src.npy')).to(DEVICE)

### load obs data
d_obs = torch.tensor(np.load('./obs_data/d_obs.npy')).to(DEVICE)
# Out:
# NT: 2000

# %%
criteria1 = torch.nn.L1Loss(reduction='sum') ### for model loss
 
vp0 = vp_initial.to(DEVICE)
vp0 = vp0.requires_grad_(True)

optimer = torch.optim.Adam([{'params': [vp0], 'lr': learn,'betas': (0.9, 0.98)}])

all_loss_data = []
all_loss_model =[]
time_each_iter = []
tv_loss = []
SNR = []
cpu_mem_log = [] 
gpu_mem_log = []

# %%
import time
t_start = time.time()

grad_accum = None
num_grads = 0


kernel_size = kernel_size
levels  = levels
sigma = sigma

levels_1 = np.arange(0,levels,1)

for level in reversed(levels_1):
    print('Now inversion on level:',level)
    for iter in range(ITERATION):
        loss_data_minibatch = []
        time_each_bath_start = time.time()
        for batch in range(mini_batches):
        
            optimer.zero_grad()
            src_loc_batch = src_loc[batch::mini_batches]
            rec_loc_batch = rec_loc[batch::mini_batches]
            src_batch = src[batch::mini_batches]
                        
            physics = Physics_deepwave(inpa['dh'], inpa['dt'], src=src_batch,
                                src_loc=src_loc_batch, rec_loc=rec_loc_batch,
                                       accuracy = inpa['accuracy'],
                                    pml_width =  inpa['pml_width']
                                )
                
            with torch.no_grad():
                if submarine == "yes":
                    vp0[:submarine_deep,:] = submarine_vp
                else:
                    vp0 = vp0
                    
                vp0[vp0>vp_true.max()] = vp_true.max()
                vp0[vp0<vp_true.min()] = vp_true.min() 
                
            vp0 = vp0.requires_grad_(True)
            taux_est = physics(vp0.squeeze()) ###[1,shots_batch,nt,receviers]
    
            d_obs1 = d_obs.unsqueeze(0)
      
            taux_est_filtered = taux_est
            d_obs_filtered = d_obs1[:, batch::mini_batches]
            
            lam_tv = 0#0.001
            tvloss = tv_l1_regularization(vp0)
            channels = taux_est.shape[1]
            dtype = torch.float
            kernel = gaussian_kernel(size=kernel_size, channels=channels, sigma=sigma, dtype=dtype, device=DEVICE)
            
            
            pyramids_obs = create_gaussian_pyramid(d_obs_filtered, kernel=kernel, levels=levels
                                                        )
            pyramids_syn = create_gaussian_pyramid(taux_est_filtered, kernel=kernel, levels=levels
                                                        )
#             for i in range(7):
#                 print('pyramids_syn.shape',pyramids_syn[i].shape)
            if loss_fn == 'l1':
                criteria = torch.nn.L1Loss(reduction='mean')
                weight = 1.0e2
            else:
                criteria =  torch.nn.MSELoss(reduction='mean')
                weight = 1.0e4
            
            loss_data = weight*criteria(pyramids_obs[level],pyramids_syn[level])
    
            loss = loss_data
            loss.backward()
            
            optimer.step()
                  
            loss_data = loss.item()
        
        all_loss_data.append(np.mean(loss_data))
        time_each_bath_end = time.time()
        tv_loss.append(lam_tv*tvloss)
        
        time_each_iter.append(time_each_bath_end - time_each_bath_start)
        
        mem_now_cpu = get_cpu_memory()
        cpu_mem_log.append(mem_now_cpu)
        mem_now_gpu = get_gpu_memory()
        gpu_mem_log.append(mem_now_gpu)
        
        snr = ComputeSNR(vp0.detach().cpu().numpy(), \
                      vp_true.detach().cpu().numpy())
        SNR = np.append(SNR, snr)
        with torch.no_grad():
            all_loss_model.append(
                criteria1(vp0, vp_true).item()
            )
        if (iter+1)%1 ==0:
            print(f"Iter {iter + 1} = loss: {all_loss_data[-1]:.4f},model: {all_loss_model[-1]:.4f},time_iter:{time_each_iter[-1]:.4f},tvloss:{tv_loss[-1]:.2f},snr_vp:{SNR[-1]:.3f}")
        if (iter+1)%10 ==0:
            np.save(vp_save_path + 'recx_iter_%s_%s.npy' % (iter + 1, level), vp0.cpu().detach().numpy())
        if (iter+1)%10 == 0:   
            fig, ax = plt.subplots(1,1, figsize=(4, 4))
            im = ax.imshow(vp0.detach().cpu(), 
                              cmap='jet', vmin=vp0.min(), 
                       vmax=vp0.max()) 
            points = ax.get_position().get_points()
            dy = points[1, 1] - points[0, 1]
    
            cax = fig.add_axes([0.91, points[0, 1], 0.02, dy])
            cax.yaxis.set_ticks_position("right")
            cbar = fig.colorbar(im, cax=cax, orientation="vertical", 
                                extend="neither", label="$V_P (m/s)$"
                                )
            plt.show()
t_end = time.time()
elapsed_time = t_end - t_start
print('Running complete in {:.0f}m  {:.0f}s' .format(elapsed_time //60 , elapsed_time % 60))
# Out:
# Now inversion on level: 4
# Iter 1 = loss: 1.5469,model: 84599744.0000,time_iter:3.8284,tvloss:0.00,snr_vp:13.624
# Iter 2 = loss: 1.4566,model: 85105288.0000,time_iter:3.7374,tvloss:0.00,snr_vp:13.533
# Iter 3 = loss: 1.4117,model: 84748496.0000,time_iter:3.7434,tvloss:0.00,snr_vp:13.494
# Iter 4 = loss: 1.3780,model: 84497704.0000,time_iter:3.7396,tvloss:0.00,snr_vp:13.485
# Iter 5 = loss: 1.3587,model: 83886528.0000,time_iter:3.7269,tvloss:0.00,snr_vp:13.514
# Iter 6 = loss: 1.3409,model: 83528496.0000,time_iter:3.7295,tvloss:0.00,snr_vp:13.548
# Iter 7 = loss: 1.3239,model: 83080112.0000,time_iter:3.7292,tvloss:0.00,snr_vp:13.584
# Iter 8 = loss: 1.3119,model: 82849808.0000,time_iter:3.7127,tvloss:0.00,snr_vp:13.625
# Iter 9 = loss: 1.2980,model: 82361128.0000,time_iter:3.7647,tvloss:0.00,snr_vp:13.675
# Iter 10 = loss: 1.2851,model: 82084720.0000,time_iter:3.7408,tvloss:0.00,snr_vp:13.737
# Iter 11 = loss: 1.2771,model: 81274424.0000,time_iter:3.7150,tvloss:0.00,snr_vp:13.801
# Iter 12 = loss: 1.2677,model: 80737712.0000,time_iter:3.6974,tvloss:0.00,snr_vp:13.864
# Iter 13 = loss: 1.2684,model: 79626600.0000,time_iter:3.7057,tvloss:0.00,snr_vp:13.948
# Iter 14 = loss: 1.2564,model: 78636720.0000,time_iter:3.7361,tvloss:0.00,snr_vp:14.029
# Iter 15 = loss: 1.2536,model: 77479000.0000,time_iter:3.6943,tvloss:0.00,snr_vp:14.120
# Iter 16 = loss: 1.2391,model: 76142048.0000,time_iter:3.6735,tvloss:0.00,snr_vp:14.210
# Iter 17 = loss: 1.2381,model: 75122912.0000,time_iter:3.6975,tvloss:0.00,snr_vp:14.291
# Iter 18 = loss: 1.2279,model: 73627448.0000,time_iter:3.7031,tvloss:0.00,snr_vp:14.394
# Iter 19 = loss: 1.2248,model: 72515728.0000,time_iter:3.7151,tvloss:0.00,snr_vp:14.476
# Iter 20 = loss: 1.2127,model: 70927472.0000,time_iter:3.7453,tvloss:0.00,snr_vp:14.580
# Iter 21 = loss: 1.2030,model: 69659552.0000,time_iter:3.7114,tvloss:0.00,snr_vp:14.673
# Iter 22 = loss: 1.2020,model: 68272880.0000,time_iter:3.6985,tvloss:0.00,snr_vp:14.751
# Iter 23 = loss: 1.1986,model: 67137224.0000,time_iter:3.7101,tvloss:0.00,snr_vp:14.860
# Iter 24 = loss: 1.1800,model: 65836780.0000,time_iter:3.7323,tvloss:0.00,snr_vp:14.922
# Iter 25 = loss: 1.2054,model: 64454680.0000,time_iter:3.7306,tvloss:0.00,snr_vp:15.054
# Iter 26 = loss: 1.1743,model: 63388996.0000,time_iter:3.7061,tvloss:0.00,snr_vp:15.120
# Iter 27 = loss: 1.1628,model: 61891960.0000,time_iter:3.7041,tvloss:0.00,snr_vp:15.264
# Iter 28 = loss: 1.1555,model: 61326916.0000,time_iter:3.7132,tvloss:0.00,snr_vp:15.332
# Iter 29 = loss: 1.1439,model: 59583296.0000,time_iter:3.7209,tvloss:0.00,snr_vp:15.484
# Iter 30 = loss: 1.1340,model: 58930960.0000,time_iter:3.7309,tvloss:0.00,snr_vp:15.589
# Now inversion on level: 3
# Iter 1 = loss: 3.0987,model: 55611104.0000,time_iter:3.7271,tvloss:0.00,snr_vp:15.930
# Iter 2 = loss: 2.9648,model: 53748396.0000,time_iter:3.7829,tvloss:0.00,snr_vp:16.172
# Iter 3 = loss: 2.8270,model: 51249368.0000,time_iter:3.7888,tvloss:0.00,snr_vp:16.436
# Iter 4 = loss: 2.8007,model: 49963700.0000,time_iter:3.7752,tvloss:0.00,snr_vp:16.626
# Iter 5 = loss: 2.7947,model: 48553408.0000,time_iter:3.7470,tvloss:0.00,snr_vp:16.821
# Iter 6 = loss: 2.6916,model: 46639616.0000,time_iter:3.7632,tvloss:0.00,snr_vp:17.068
# Iter 7 = loss: 2.6953,model: 45279736.0000,time_iter:3.7623,tvloss:0.00,snr_vp:17.283
# Iter 8 = loss: 2.6422,model: 43424492.0000,time_iter:3.7683,tvloss:0.00,snr_vp:17.549
# Iter 9 = loss: 2.6358,model: 41997908.0000,time_iter:3.7735,tvloss:0.00,snr_vp:17.785
# Iter 10 = loss: 2.5568,model: 40817576.0000,time_iter:3.7383,tvloss:0.00,snr_vp:18.035
# Iter 11 = loss: 2.5354,model: 39303272.0000,time_iter:3.7089,tvloss:0.00,snr_vp:18.262
# Iter 12 = loss: 2.4714,model: 38275816.0000,time_iter:3.7231,tvloss:0.00,snr_vp:18.509
# Iter 13 = loss: 2.4574,model: 37051340.0000,time_iter:3.7305,tvloss:0.00,snr_vp:18.735
# Iter 14 = loss: 2.4121,model: 35910216.0000,time_iter:3.7028,tvloss:0.00,snr_vp:18.981
# Iter 15 = loss: 2.3770,model: 34766716.0000,time_iter:3.7106,tvloss:0.00,snr_vp:19.208
# Iter 16 = loss: 2.3126,model: 33961012.0000,time_iter:3.7216,tvloss:0.00,snr_vp:19.432
# Iter 17 = loss: 2.3022,model: 32882590.0000,time_iter:3.7250,tvloss:0.00,snr_vp:19.615
# Iter 18 = loss: 2.2775,model: 32398916.0000,time_iter:3.7551,tvloss:0.00,snr_vp:19.795
# Iter 19 = loss: 2.2996,model: 31395752.0000,time_iter:3.7040,tvloss:0.00,snr_vp:19.964
# Iter 20 = loss: 2.2616,model: 31035776.0000,time_iter:3.7100,tvloss:0.00,snr_vp:20.133
# Iter 21 = loss: 2.2614,model: 30039906.0000,time_iter:3.7183,tvloss:0.00,snr_vp:20.318
# Iter 22 = loss: 2.2051,model: 29544860.0000,time_iter:3.7414,tvloss:0.00,snr_vp:20.504
# Iter 23 = loss: 2.2238,model: 28758636.0000,time_iter:3.7357,tvloss:0.00,snr_vp:20.681
# Iter 24 = loss: 2.1831,model: 28398136.0000,time_iter:3.7322,tvloss:0.00,snr_vp:20.810
# Iter 25 = loss: 2.2703,model: 27910546.0000,time_iter:3.7232,tvloss:0.00,snr_vp:20.980
# Iter 26 = loss: 2.1815,model: 27603150.0000,time_iter:3.7267,tvloss:0.00,snr_vp:21.061
# Iter 27 = loss: 2.2751,model: 27291572.0000,time_iter:3.7489,tvloss:0.00,snr_vp:21.186
# Iter 28 = loss: 2.2316,model: 27088526.0000,time_iter:3.7095,tvloss:0.00,snr_vp:21.241
# Iter 29 = loss: 2.4499,model: 26649420.0000,time_iter:3.7245,tvloss:0.00,snr_vp:21.355
# Iter 30 = loss: 2.2432,model: 26382816.0000,time_iter:3.6861,tvloss:0.00,snr_vp:21.395
# Now inversion on level: 2
# Iter 1 = loss: 5.1690,model: 25803202.0000,time_iter:3.7011,tvloss:0.00,snr_vp:21.626
# Iter 2 = loss: 5.4833,model: 25327360.0000,time_iter:3.7009,tvloss:0.00,snr_vp:21.813
# Iter 3 = loss: 5.4121,model: 24703588.0000,time_iter:3.7382,tvloss:0.00,snr_vp:21.945
# Iter 4 = loss: 5.3554,model: 24353334.0000,time_iter:3.7333,tvloss:0.00,snr_vp:22.020
# Iter 5 = loss: 5.5297,model: 23939336.0000,time_iter:3.7253,tvloss:0.00,snr_vp:22.128
# Iter 6 = loss: 5.2657,model: 23838266.0000,time_iter:3.7356,tvloss:0.00,snr_vp:22.169
# Iter 7 = loss: 5.4453,model: 23653930.0000,time_iter:3.7349,tvloss:0.00,snr_vp:22.211
# Iter 8 = loss: 5.0561,model: 23616032.0000,time_iter:3.7508,tvloss:0.00,snr_vp:22.209
# Iter 9 = loss: 5.2222,model: 23300372.0000,time_iter:3.7671,tvloss:0.00,snr_vp:22.262
# Iter 10 = loss: 5.2216,model: 23494644.0000,time_iter:3.7719,tvloss:0.00,snr_vp:22.276
# Iter 11 = loss: 5.0915,model: 23223378.0000,time_iter:3.7820,tvloss:0.00,snr_vp:22.329
# Iter 12 = loss: 5.0411,model: 23169084.0000,time_iter:3.7448,tvloss:0.00,snr_vp:22.357
# Iter 13 = loss: 5.2903,model: 23069216.0000,time_iter:3.7559,tvloss:0.00,snr_vp:22.429
# Iter 14 = loss: 5.1848,model: 23149620.0000,time_iter:3.7802,tvloss:0.00,snr_vp:22.421
# Iter 15 = loss: 5.3053,model: 23154088.0000,time_iter:3.7607,tvloss:0.00,snr_vp:22.452
# Iter 16 = loss: 5.3043,model: 22849864.0000,time_iter:3.7615,tvloss:0.00,snr_vp:22.466
# Iter 17 = loss: 5.1205,model: 22756772.0000,time_iter:3.7743,tvloss:0.00,snr_vp:22.484
# Iter 18 = loss: 5.4433,model: 22647574.0000,time_iter:3.7471,tvloss:0.00,snr_vp:22.523
# Iter 19 = loss: 5.0722,model: 22810896.0000,time_iter:3.7494,tvloss:0.00,snr_vp:22.511
# Iter 20 = loss: 5.1340,model: 22547250.0000,time_iter:3.7693,tvloss:0.00,snr_vp:22.560
# Iter 21 = loss: 5.0212,model: 22494008.0000,time_iter:3.7370,tvloss:0.00,snr_vp:22.577
# Iter 22 = loss: 4.9746,model: 22218698.0000,time_iter:3.7296,tvloss:0.00,snr_vp:22.637
# Iter 23 = loss: 5.0055,model: 22128234.0000,time_iter:3.7291,tvloss:0.00,snr_vp:22.671
# Iter 24 = loss: 5.0246,model: 21983844.0000,time_iter:3.7071,tvloss:0.00,snr_vp:22.697
# Iter 25 = loss: 5.1810,model: 22090734.0000,time_iter:3.7245,tvloss:0.00,snr_vp:22.700
# Iter 26 = loss: 5.0041,model: 22042284.0000,time_iter:3.7146,tvloss:0.00,snr_vp:22.684
# Iter 27 = loss: 5.1656,model: 21959314.0000,time_iter:3.7104,tvloss:0.00,snr_vp:22.717
# Iter 28 = loss: 4.9693,model: 22166120.0000,time_iter:3.7254,tvloss:0.00,snr_vp:22.690
# Iter 29 = loss: 5.1291,model: 22144008.0000,time_iter:3.7286,tvloss:0.00,snr_vp:22.713
# Iter 30 = loss: 4.9744,model: 22044392.0000,time_iter:3.7426,tvloss:0.00,snr_vp:22.725
# Now inversion on level: 1
# Iter 1 = loss: 11.3646,model: 22391486.0000,time_iter:3.7249,tvloss:0.00,snr_vp:22.742
# Iter 2 = loss: 11.8489,model: 23295612.0000,time_iter:3.7271,tvloss:0.00,snr_vp:22.639
# Iter 3 = loss: 11.3890,model: 22693054.0000,time_iter:3.7286,tvloss:0.00,snr_vp:22.667
# Iter 4 = loss: 11.8528,model: 22701964.0000,time_iter:3.7184,tvloss:0.00,snr_vp:22.661
# Iter 5 = loss: 11.7036,model: 22368708.0000,time_iter:3.7419,tvloss:0.00,snr_vp:22.669
# Iter 6 = loss: 11.3863,model: 22124866.0000,time_iter:3.7450,tvloss:0.00,snr_vp:22.689
# Iter 7 = loss: 10.8426,model: 21767244.0000,time_iter:3.7073,tvloss:0.00,snr_vp:22.730
# Iter 8 = loss: 11.4307,model: 21843280.0000,time_iter:3.7139,tvloss:0.00,snr_vp:22.742
# Iter 9 = loss: 11.3097,model: 21838592.0000,time_iter:3.7179,tvloss:0.00,snr_vp:22.740
# Iter 10 = loss: 11.5742,model: 22184092.0000,time_iter:3.7417,tvloss:0.00,snr_vp:22.708
# Iter 11 = loss: 11.3869,model: 22194332.0000,time_iter:3.7260,tvloss:0.00,snr_vp:22.721
# Iter 12 = loss: 11.5814,model: 22430030.0000,time_iter:3.7395,tvloss:0.00,snr_vp:22.667
# Iter 13 = loss: 12.2387,model: 22470492.0000,time_iter:3.7089,tvloss:0.00,snr_vp:22.631
# Iter 14 = loss: 11.6881,model: 22892602.0000,time_iter:3.7178,tvloss:0.00,snr_vp:22.554
# Iter 15 = loss: 11.6062,model: 22523080.0000,time_iter:3.7233,tvloss:0.00,snr_vp:22.582
# Iter 16 = loss: 11.2789,model: 22543782.0000,time_iter:3.7330,tvloss:0.00,snr_vp:22.610
# Iter 17 = loss: 11.8205,model: 22499132.0000,time_iter:3.7459,tvloss:0.00,snr_vp:22.604
# Iter 18 = loss: 11.4570,model: 22628544.0000,time_iter:3.7520,tvloss:0.00,snr_vp:22.544
# Iter 19 = loss: 11.9876,model: 22689600.0000,time_iter:3.7463,tvloss:0.00,snr_vp:22.503
# Iter 20 = loss: 11.4134,model: 22659216.0000,time_iter:3.7511,tvloss:0.00,snr_vp:22.514
# Iter 21 = loss: 11.6497,model: 22840046.0000,time_iter:3.7662,tvloss:0.00,snr_vp:22.532
# Iter 22 = loss: 11.4670,model: 22733864.0000,time_iter:3.7654,tvloss:0.00,snr_vp:22.547
# Iter 23 = loss: 11.5732,model: 22885856.0000,time_iter:3.7401,tvloss:0.00,snr_vp:22.551
# Iter 24 = loss: 11.5962,model: 22630008.0000,time_iter:3.7864,tvloss:0.00,snr_vp:22.570
# Iter 25 = loss: 11.6421,model: 22795272.0000,time_iter:3.7504,tvloss:0.00,snr_vp:22.593
# Iter 26 = loss: 11.5270,model: 22634716.0000,time_iter:3.7412,tvloss:0.00,snr_vp:22.576
# Iter 27 = loss: 11.9431,model: 23019200.0000,time_iter:3.7825,tvloss:0.00,snr_vp:22.547
# Iter 28 = loss: 12.0516,model: 22792088.0000,time_iter:3.7303,tvloss:0.00,snr_vp:22.538
# Iter 29 = loss: 11.8326,model: 23136218.0000,time_iter:3.7304,tvloss:0.00,snr_vp:22.514
# Iter 30 = loss: 11.7271,model: 22855228.0000,time_iter:3.7278,tvloss:0.00,snr_vp:22.527
# Now inversion on level: 0
# Iter 1 = loss: 48.5406,model: 23087836.0000,time_iter:3.7064,tvloss:0.00,snr_vp:22.515
# Iter 2 = loss: 49.7435,model: 22744218.0000,time_iter:3.7066,tvloss:0.00,snr_vp:22.492
# Iter 3 = loss: 47.7509,model: 23352444.0000,time_iter:3.7297,tvloss:0.00,snr_vp:22.372
# Iter 4 = loss: 48.7283,model: 23126800.0000,time_iter:3.7279,tvloss:0.00,snr_vp:22.378
# Iter 5 = loss: 48.1993,model: 23051976.0000,time_iter:3.7411,tvloss:0.00,snr_vp:22.403
# Iter 6 = loss: 48.7178,model: 23443266.0000,time_iter:3.7622,tvloss:0.00,snr_vp:22.415
# Iter 7 = loss: 48.3007,model: 23478168.0000,time_iter:3.7491,tvloss:0.00,snr_vp:22.446
# Iter 8 = loss: 48.4975,model: 23164316.0000,time_iter:3.7373,tvloss:0.00,snr_vp:22.506
# Iter 9 = loss: 48.0155,model: 22368820.0000,time_iter:3.7273,tvloss:0.00,snr_vp:22.579
# Iter 10 = loss: 48.0363,model: 22545888.0000,time_iter:3.7253,tvloss:0.00,snr_vp:22.572
# Iter 11 = loss: 48.9010,model: 23120860.0000,time_iter:3.7219,tvloss:0.00,snr_vp:22.497
# Iter 12 = loss: 48.3999,model: 23847656.0000,time_iter:3.7172,tvloss:0.00,snr_vp:22.367
# Iter 13 = loss: 49.0520,model: 23745956.0000,time_iter:3.7259,tvloss:0.00,snr_vp:22.364
# Iter 14 = loss: 48.5728,model: 24375800.0000,time_iter:3.7102,tvloss:0.00,snr_vp:22.277
# Iter 15 = loss: 49.3854,model: 24711072.0000,time_iter:3.7048,tvloss:0.00,snr_vp:22.251
# Iter 16 = loss: 48.0516,model: 25521096.0000,time_iter:3.7105,tvloss:0.00,snr_vp:22.129
# Iter 17 = loss: 49.2201,model: 24847048.0000,time_iter:3.7000,tvloss:0.00,snr_vp:22.158
# Iter 18 = loss: 48.4001,model: 24541926.0000,time_iter:3.7157,tvloss:0.00,snr_vp:22.148
# Iter 19 = loss: 48.3595,model: 24651702.0000,time_iter:3.7225,tvloss:0.00,snr_vp:22.155
# Iter 20 = loss: 48.5499,model: 24417132.0000,time_iter:3.7096,tvloss:0.00,snr_vp:22.150
# Iter 21 = loss: 48.1232,model: 24537296.0000,time_iter:3.7268,tvloss:0.00,snr_vp:22.164
# Iter 22 = loss: 48.9015,model: 24594376.0000,time_iter:3.7042,tvloss:0.00,snr_vp:22.160
# Iter 23 = loss: 48.2865,model: 24420198.0000,time_iter:3.6417,tvloss:0.00,snr_vp:22.173
# Iter 24 = loss: 48.3242,model: 24444278.0000,time_iter:3.7067,tvloss:0.00,snr_vp:22.214
# Iter 25 = loss: 48.4604,model: 24403648.0000,time_iter:3.7034,tvloss:0.00,snr_vp:22.195
# Iter 26 = loss: 49.2084,model: 24977364.0000,time_iter:3.7437,tvloss:0.00,snr_vp:22.129
# Iter 27 = loss: 49.3650,model: 24467260.0000,time_iter:3.7403,tvloss:0.00,snr_vp:22.155
# Iter 28 = loss: 48.3728,model: 24177632.0000,time_iter:3.7435,tvloss:0.00,snr_vp:22.209
# Iter 29 = loss: 48.3163,model: 24221430.0000,time_iter:3.7708,tvloss:0.00,snr_vp:22.180
# Iter 30 = loss: 49.4275,model: 24960498.0000,time_iter:3.7774,tvloss:0.00,snr_vp:22.101
# Running complete in 9m  31s

# %%
with torch.no_grad():
    np.savetxt(main_path +'all_loss_data.txt', all_loss_data,delimiter=',')
    np.savetxt(main_path +'elapsed_time.txt', time_each_iter,delimiter=',')
    np.savetxt(main_path + 'all_loss_model.txt', all_loss_model, delimiter=',')
    np.savetxt(main_path + 'snr.txt', SNR, delimiter=',')
    np.savetxt(main_path+'cpu_men_log.txt',cpu_mem_log , delimiter=',')
    np.savetxt(main_path+'gpu_men_log.txt',gpu_mem_log , delimiter=',')

# %%
torch.cuda.empty_cache()
